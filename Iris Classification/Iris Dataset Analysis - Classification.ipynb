# %% [markdown]
# # Loading Dataset

# %%
# Import Library packagies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Loading Dataset
Iris = pd.read_csv(r'C:\Users\Dell\OneDrive\Documents\AI\MACHINE LEARNING\Iris.csv')

# %%
# Display Data head(first five)
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Display Data tail(last five)
Iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# Remove Id()
Iris.drop('Id', axis = 1, inplace = True)

# %%
# Display information of the data
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# To display stat about data
Iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# Find how many colums and rows
Iris.shape
# Out:
# (150, 5)

# %%
# To Display no. of samples on each class
Iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# Find the total number of cm
Iris.count()
# Out:
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %% [markdown]
# # Preprocessing The Dataset

# %%
#Check for null values
Iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Scatter plot for Sepal Length and Width
fig = Iris[Iris.Species == 'Iris-setosa'].plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'blue', label = 'Iris-setosa')
Iris[Iris.Species == 'Iris-versicolor'].plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'orange', label = 'Iris-versicolor', ax=fig)
Iris[Iris.Species == 'Iris-virginica'].plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'red', label = 'Iris-virginica', ax=fig)

fig.set_xlabel('Setosa')
fig.set_ylabel('virginica')
fig.set_title('SepalLength VS SepalWidth')
fig = plt.gcf()
fig.set_size_inches(12,6)
plt.legend()
plt.show()

# %%
# Scatter plot for Petal Length and Width
fig = Iris[Iris.Species == 'Iris-setosa'].plot(kind = 'scatter', x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'blue', label = 'Iris-setosa')
Iris[Iris.Species == 'Iris-versicolor'].plot(kind = 'scatter', x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'orange', label = 'Iris-versicolor', ax=fig)
Iris[Iris.Species == 'Iris-virginica'].plot(kind = 'scatter', x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'red', label = 'Iris-virginica', ax=fig)

fig.set_xlabel('Setosa')
fig.set_ylabel('virginica')
fig.set_title('PetalLength VS PetalWidth')
fig = plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
# Scatter plot for Sepal Length and Petal Length
fig = Iris[Iris.Species == 'Iris-setosa'].plot(kind = 'scatter', x = 'SepalLengthCm', y = 'PetalLengthCm', color = 'blue', label = 'Iris-setosa')
Iris[Iris.Species == 'Iris-versicolor'].plot(kind = 'scatter', x = 'SepalLengthCm', y = 'PetalLengthCm', color = 'orange', label = 'Iris-versicolor', ax=fig)
Iris[Iris.Species == 'Iris-virginica'].plot(kind = 'scatter', x = 'SepalLengthCm', y = 'PetalLengthCm', color = 'red', label = 'Iris-virginica', ax=fig)

fig.set_xlabel('Setosa')
fig.set_ylabel('virginica')
fig.set_title('SepalLength VS PetalLength')
fig = plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
# Scatter plot for Sepal Width and Petal Width
fig = Iris[Iris.Species == 'Iris-setosa'].plot(kind = 'scatter', x = 'SepalWidthCm', y = 'PetalWidthCm', color = 'blue', label = 'Iris-setosa')
Iris[Iris.Species == 'Iris-versicolor'].plot(kind = 'scatter', x = 'SepalWidthCm', y = 'PetalWidthCm', color = 'orange', label = 'Iris-versicolor', ax=fig)
Iris[Iris.Species == 'Iris-virginica'].plot(kind = 'scatter', x = 'SepalWidthCm', y = 'PetalWidthCm', color = 'red', label = 'Iris-virginica', ax=fig)

fig.set_xlabel('Setosa')
fig.set_ylabel('virginica')
fig.set_title('SepalWidth VS PetalWidth')
fig = plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
# Get Histogram of the data
Iris.hist(edgecolor = 'brown', linewidth = 1.5, color = 'pink')
fig = plt.gcf()
fig.set_size_inches(12, 9)
plt.show()

# %%
# General plot 
import seaborn as sns
sns.pairplot(Iris)

# %% [markdown]
# # Correlation Matrix

# %%
Iris.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
import seaborn as sns
corr = Iris.corr()
fig, ax = plt.subplots(figsize = (5,4))
sns.heatmap(corr, annot = True, ax =ax, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
Iris['Species'] = le.fit_transform(Iris['Species'])
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
# train - 70
# test -30
x = Iris.drop(columns=['Species'])
y = Iris['Species']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %%
# Logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# Model Training
model.fit(x_train, y_train)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Print metrics to get performance
print('Acuracy: ', model.score(x_test, y_test) * 100)
# Out:
# Acuracy:  95.55555555555556

# %%
# knn - k - nearest neighbour
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Print metrics to get performance
print('Acuracy: ', model.score(x_test, y_test) * 100)
# Out:
# Acuracy:  95.55555555555556

# %%
# decidion tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Print metrics to get performance
print('Acuracy: ', model.score(x_test, y_test) * 100)
# Out:
# Acuracy:  95.55555555555556
